# %%
1) BEGIN
2) READ customer items
3) COMPUTE total price
4) OUTPUT "Do you have a loyalty card"
5) IF customer has loyalty card THEN
6)     READ loyalty card
7)     COMPUTE discounts
8) ELSE
9)     OUTPUT total amount
10)ENDIF
11)OUTPUT "Which payment method"
12)IF payment is successful THEN
13)    PRINT receipt
14)    ASSIGN items into bags
15)    OUTPUT "Thank you for shopping with us"
16)ELSE
17)    OUTPUT "Payment failed. Please try again."
18)ENDIF
19)END

# %% [markdown]
# ![Flowchart.png](attachment:bd382918-fb23-493b-bf06-05fc9d3553bc.png)

# %% [markdown]
# ![Flowchart1.png](attachment:3c502d4b-129a-4b90-8af1-c481d42fc924.png)

# %% [markdown]
# ![Flowchart2.png](attachment:086bbfbc-24e5-49e2-9001-6a8e97cffd5e.png)
